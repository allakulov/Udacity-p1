# %% [markdown]
# # Udacity project 1
# ## Ease of doing business and corruption: what's the relationship?

# %% [markdown]
# Part 1: Analysis of the Ease of Doing Business Index

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
# Load the EDBI dataset
df_edbi = pd.read_csv("doingbusiness.csv")
df_edbi.head()
# Out:
#                Economy    Year  \
# 0          Afghanistan  DB2019
# 1              Albania  DB2019
# 2              Algeria  DB2019
# 3               Angola  DB2019
# 4  Antigua and Barbuda  DB2019
#
#    Ease of doing business score (DB17-20 methodology)  \
# 0                                               44.2
# 1                                               67.0
# 2                                               48.5
# 3                                               41.2
# 4                                               59.9
#
#    Rank-Starting a business  Score-Starting a business  \
# 0                       NaN                       92.0
# 1                       NaN                       91.7
# 2                       NaN                       77.9
# 3                       NaN                       79.0
# 4                       NaN                       81.7
#
#    Starting a Business - Procedures - Men (number)  \
# 0                                                4
# 1                                                5
# 2                                               12
# 3                                                8
# 4                                                9
#
#    Starting a Business - Time - Men (days)  \
# 0                                      8.0
# 1                                      4.5
# 2                                     18.0
# 3                                     36.0
# 4                                     22.0
#
#    Starting a Business - Cost - Men (% of income per capita)  \
# 0                                                6.4
# 1                                               11.3
# 2                                               11.8
# 3                                               13.9
# 4                                                8.7
#
#    Starting a Business - Procedures - Women (number)  \
# 0                                                  5
# 1                                                  5
# 2                                                 12
# 3                                                  8
# 4                                                  9
#
#    Starting a Business - Time - Women (days)  ...  Score-Resolving insolvency  \
# 0                                        9.0  ...                        51.8
# 1                                        4.5  ...                        67.4
# 2                                       18.0  ...                        49.2
# 3                                       36.0  ...                         0.0
# 4                                       22.0  ...                        35.4
#
#    Resolving Insolvency - Outcome (0 as piecemeal sale and 1 as going concern)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Resolving Insolvency - Time (years)  \
# 0                                    2
# 1                                    2
# 2                                  1.3
# 3                          No Practice
# 4                                    3
#
#    Resolving Insolvency - Cost (% of estate)  \
# 0                                         25
# 1                                         10
# 2                                          7
# 3                                No Practice
# 4                                          7
#
#    Resolving Insolvency - Recovery rate (cents on the dollar)  \
# 0                                               26.5
# 1                                               44.0
# 2                                               50.8
# 3                                                0.0
# 4                                               36.8
#
#   Resolving Insolvency - Strength of insolvency framework index (0-16)  \
# 0                                               12.0
# 1                                               14.0
# 2                                                7.0
# 3                                                0.0
# 4                                                5.0
#
#   Resolving Insolvency - Commencement of proceedings index (0-3) (DB15-20 methodology)  \
# 0                                                2.0
# 1                                                3.0
# 2                                                3.0
# 3                                                2.0
# 4                                                2.0
#
#   Resolving Insolvency - Management of debtor's assets index (0-6) (DB15-20 methodology)  \
# 0                                                6.0
# 1                                                6.0
# 2                                                2.0
# 3                                                4.0
# 4                                                2.0
#
#   Resolving Insolvency - Reorganization proceedings index (0-3) (DB15-20 methodology)  \
# 0                                                2.0
# 1                                                3.0
# 2                                                1.0
# 3                                                0.0
# 4                                                0.0
#
#   Resolving Insolvency - Creditor participation index (0-4) (DB15-20 methodology)
# 0                                                  2
# 1                                                  2
# 2                                                  1
# 3                                                  0
# 4                                                  1
#
# [5 rows x 136 columns]

# %%
# Pre-processing data 
    ## Set Economy column as the index
    ## Retain only columns that start with "Sco", which captures the columns with scores
    ## Shorten variables names
    ## Drop columns with NaN
df_edbi = df_edbi.set_index('Economy')
df_edbi = df_edbi[df_edbi.columns[pd.Series(df_edbi.columns).str.startswith('Sco')]]
df_edbi.rename(columns = lambda x: x.split('(')[0].replace('Score-', ''), inplace = True)
df_edbi.dropna(axis = 1, inplace = True)
df_edbi.head()
# Out:
#                      Starting a business  Dealing with construction permits   \
# Economy
# Afghanistan                         92.0                                34.5
# Albania                             91.7                                52.6
# Algeria                             77.9                                64.6
# Angola                              79.0                                65.0
# Antigua and Barbuda                 81.7                                65.6
#
#                      Getting electricity   Registering property   \
# Economy
# Afghanistan                          44.5                   27.5
# Albania                              64.6                   62.9
# Algeria                              71.9                   44.3
# Angola                               54.1                   43.1
# Antigua and Barbuda                  80.4                   56.6
#
#                      Getting credit   Protecting minority investors   \
# Economy
# Afghanistan                       50                            36.0
# Albania                           70                            46.0
# Algeria                           10                            20.0
# Angola                             5                            32.0
# Antigua and Barbuda               25                            58.0
#
#                      Paying taxes   Trading across borders   \
# Economy
# Afghanistan                   43.3                     30.6
# Albania                       64.9                     96.3
# Algeria                       53.9                     38.4
# Angola                        69.5                     36.2
# Antigua and Barbuda           59.0                     68.7
#
#                      Enforcing contracts   Resolving insolvency
# Economy
# Afghanistan                          31.8                  51.8
# Albania                              53.5                  67.4
# Algeria                              54.8                  49.2
# Angola                               28.1                   0.0
# Antigua and Barbuda                  68.1                  35.4

# %%
# Add a column Country and reset index
# Check the country names
df_edbi['Country'] = df_edbi.index

df_edbi["Country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh',
#        'Bangladesh - Chittagong', 'Bangladesh - Dhaka', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Brazil - Rio de Janeiro', 'Brazil - São Paulo',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada',
#        'Central African Republic', 'Chad', 'Chile', 'China',
#        'China - Beijing', 'China - Shanghai', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Côte d'Ivoire",
#        'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Fiji', 'Finland', 'France', 'Gabon',
#        'Gambia, The', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Honduras', 'Hong Kong SAR, China', 'Hungary', 'Iceland', 'India',
#        'India - Delhi', 'India - Mumbai', 'Indonesia',
#        'Indonesia - Jakarta', 'Indonesia - Surabaya',
#        'Iran, Islamic Rep.', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Japan - Osaka', 'Japan - Tokyo', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Kiribati', 'Korea, Rep.', 'Kosovo',
#        'Kuwait', 'Kyrgyz Republic', 'Lao PDR', 'Latvia', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein*', 'Lithuania',
#        'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives',
#        'Mali', 'Malta', 'Marshall Islands', 'Mauritania', 'Mauritius',
#        'Mexico', 'Mexico - Mexico City', 'Mexico - Monterrey',
#        'Micronesia, Fed. Sts.', 'Moldova', 'Mongolia', 'Montenegro',
#        'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nepal',
#        'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'Nigeria - Kano', 'Nigeria - Lagos', 'North Macedonia', 'Norway',
#        'Oman', 'Pakistan', 'Pakistan - Karachi', 'Pakistan - Lahore',
#        'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Romania', 'Russian Federation', 'Russian Federation - Moscow',
#        'Russian Federation - Saint Petersburg', 'Rwanda', 'Samoa',
#        'San Marino', 'São Tomé and Príncipe', 'Saudi Arabia', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Slovak Republic', 'Slovenia', 'Solomon Islands', 'Somalia',
#        'South Africa', 'South Sudan', 'Spain', 'Sri Lanka',
#        'St. Kitts and Nevis', 'St. Lucia',
#        'St. Vincent and the Grenadines', 'Sudan', 'Suriname', 'Sweden',
#        'Switzerland', 'Syrian Arab Republic', 'Taiwan, China',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor-Leste', 'Togo',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'United States - Los Angeles',
#        'United States - New York City', 'Uruguay', 'Uzbekistan',
#        'Vanuatu', 'Venezuela, RB', 'Vietnam', 'West Bank and Gaza',
#        'Yemen, Rep.', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
# Clean country names
    ## Keep the first part of the names separated by a comma
df_edbi['Country'] = df_edbi['Country'].str.split(",").str[0]
    
    ## Remove cities, which contain string "-"
to_drop = df_edbi["Country"].filter(like='-', axis=0)
df_edbi = df_edbi[df_edbi["Country"].isin(to_drop) == False]
df_edbi.shape
# Out:
# (189, 11)

# %%
#Calculate the index for each country as the mean of rows
df_edbi["EDBI"] = df_edbi.mean(axis = 1)

# %%
# Check data types
df_edbi.dtypes
# Out:
# Starting a business                   float64
# Dealing with construction permits     float64
# Getting electricity                   float64
# Registering property                  float64
# Getting credit                          int64
# Protecting minority investors         float64
# Paying taxes                          float64
# Trading across borders                float64
# Enforcing contracts                   float64
# Resolving insolvency                  float64
# Country                                object
# EDBI                                  float64
# dtype: object

# %%
# Cast the integer column as float
df_edbi["Getting credit "]  = df_edbi["Getting credit "].astype("float")
df_edbi.dtypes
# Out:
# Starting a business                   float64
# Dealing with construction permits     float64
# Getting electricity                   float64
# Registering property                  float64
# Getting credit                        float64
# Protecting minority investors         float64
# Paying taxes                          float64
# Trading across borders                float64
# Enforcing contracts                   float64
# Resolving insolvency                  float64
# Country                                object
# EDBI                                  float64
# dtype: object

# %%
# Plot the distribution of variables
    ## subset dataset to exlude the country column, which contains strings
to_plot = df_edbi.drop(["Country"], axis = 1)

    ## select a color palette
sb.set_palette("Dark2")

    ## plot column by column
for x in to_plot.columns:
    sb.distplot(to_plot[x], hist = False, label = x, axlabel = False)
plt.legend(bbox_to_anchor=(1.1, 1), loc=2, borderaxespad=0)

# %%
# Top five countries according to their EDBI score 
df_edbi.reset_index(drop=True, inplace=True)
edbi_top5 = df_edbi.sort_values("EDBI", ascending= False).head()
edbi_top5
# Out:
#      Starting a business  Dealing with construction permits   \
# 120                100.0                                86.5
# 149                 98.2                                84.7
# 44                  92.5                                86.9
# 71                  98.1                                91.2
# 87                  93.4                                84.4
#
#      Getting electricity   Registering property   Getting credit   \
# 120                  84.0                   94.6            100.0
# 149                  91.3                   83.1             75.0
# 44                   90.2                   89.9             70.0
# 71                   99.3                   73.6             75.0
# 87                   99.9                   76.3             65.0
#
#      Protecting minority investors   Paying taxes   Trading across borders   \
# 120                            86.0           91.1                     84.6
# 149                            86.0           91.6                     89.6
# 44                             72.0           91.1                    100.0
# 71                             84.0           99.7                     95.0
# 87                             74.0           86.9                     92.5
#
#      Enforcing contracts   Resolving insolvency        Country   EDBI
# 120                  71.5                  71.8    New Zealand  87.01
# 149                  84.5                  74.3      Singapore  85.83
# 44                   73.9                  85.1        Denmark  85.16
# 71                   69.1                  65.7  Hong Kong SAR  85.07
# 87                   84.1                  83.0          Korea  83.95

# %%
# Bottom five countries according to their EDBI score 
edbi_bottom5 = df_edbi.sort_values("EDBI", ascending= True).head()
edbi_bottom5
# Out:
#      Starting a business  Dealing with construction permits   \
# 153                 46.4                                 0.0
# 52                  51.9                                 0.0
# 186                 67.0                                 0.0
# 183                 25.0                                56.0
# 96                  73.6                                 0.0
#
#      Getting electricity   Registering property   Getting credit   \
# 153                   0.0                   47.9              0.0
# 52                    0.0                   35.3              0.0
# 186                   0.0                   65.2              0.0
# 183                  40.4                   49.7             40.0
# 96                   59.1                    0.0              0.0
#
#      Protecting minority investors   Paying taxes   Trading across borders   \
# 153                             0.0            0.0                     51.6
# 52                             16.0           55.9                      0.0
# 186                            26.0           74.1                      0.0
# 183                            24.0           12.9                      7.9
# 96                             18.0           63.6                     64.7
#
#      Enforcing contracts   Resolving insolvency    Country   EDBI
# 153                  54.6                   0.0    Somalia  20.05
# 52                   55.9                   0.0    Eritrea  21.50
# 186                  48.5                  25.9      Yemen  30.67
# 183                  46.9                  18.6  Venezuela  32.14
# 96                   48.4                   0.0      Libya  32.74

# %%
# graph top and bottom countries together
edbi_bottom5.sort_values("EDBI", ascending = False, inplace = True)
edbi_compare = pd.concat([edbi_top5, edbi_bottom5])
edbi_compare["Top5"] = edbi_compare["EDBI"] > 45

plt.figure(figsize=(10,6))
sb.set_palette("Set1")

barplot = sb.barplot(edbi_compare["Country"], edbi_compare["EDBI"], hue = edbi_compare["Top5"], dodge = False)
barplot.set_xticklabels(barplot.get_xticklabels(), rotation=40, ha="right")

barplot.get_legend().remove()
plt.show()

# %% [markdown]
# Part 2: analysis of the Corruption Perception Index

# %%
# Load Corruption Perception Index (CPI) dataset and inspect the variables
df_cpi = pd.read_csv("cpi.csv", skiprows = 2)
df_cpi.columns
# Out:
# Index(['Country', 'ISO3', 'Region', 'CPI score 2019', 'Rank',
#        'standard error ', 'Number of sources', 'Lower CI', 'Upper CI',
#        'African Development Bank CPIA',
#        'Bertelsmann Foundation Sustainable Governance Index',
#        'Bertelsmann Foundation Transformation Index',
#        'Economist Intelligence Unit Country Ratings',
#        'Freedom House Nations in Transit Ratings',
#        'Global Insight Country Risk Ratings',
#        'IMD World Competitiveness Yearbook', 'PERC Asia Risk Guide',
#        'PRS International Country Risk Guide',
#        'Varieties of Democracy Project', 'World Bank CPIA',
#        'World Economic Forum EOS', 'World Justice Project Rule of Law Index'],
#       dtype='object')

# %%
# Select country and CPI variables
df_cpi= df_cpi[["Country", "CPI score 2019"]]
df_cpi.columns = ["Country", "CPI"]
df_cpi.head()
# Out:
#        Country  CPI
# 0      Denmark   87
# 1  New Zealand   87
# 2      Finland   86
# 3    Singapore   85
# 4       Sweden   85

# %%
# Top 5 countries according to the CPI score
cpi_top5 = df_cpi.sort_values("CPI", ascending= False).head()
cpi_top5
# Out:
#        Country  CPI
# 0      Denmark   87
# 1  New Zealand   87
# 2      Finland   86
# 5  Switzerland   85
# 3    Singapore   85

# %%
# Bottom 5 countries according to the CPI score

cpi_bottom5 = df_cpi.sort_values("CPI", ascending= True).head()
cpi_bottom5
# Out:
#          Country  CPI
# 179      Somalia    9
# 178  South Sudan   12
# 177        Syria   13
# 176        Yemen   15
# 174        Sudan   16

# %%
# graph top and bottom countries together
cpi_bottom5.sort_values("CPI", ascending = False, inplace = True)
cpi_compare = pd.concat([cpi_top5, cpi_bottom5])
cpi_compare["Top5"] = cpi_compare["CPI"] > 45

plt.figure(figsize=(10,6))
sb.set_palette("Set1")

barplot = sb.barplot(cpi_compare["Country"], cpi_compare["CPI"], hue = cpi_compare["Top5"], dodge = False)
barplot.set_xticklabels(barplot.get_xticklabels(), rotation=40, ha="right")

barplot.get_legend().remove()
plt.show()

# %% [markdown]
# Part 3: Analysis of the relationship between the CPI and EDBI data

# %%
# Check the dimension of dataset
df_edbi.shape, df_cpi.shape
# Out:
# ((189, 12), (180, 2))

# %%
# Subset the EDBI dataset before merging
df_edbi = df_edbi[["Country", "EDBI"]]
df_edbi.head()
# Out:
#                Country   EDBI
# 0          Afghanistan  44.20
# 1              Albania  66.99
# 2              Algeria  48.50
# 3               Angola  41.20
# 4  Antigua and Barbuda  59.85

# %%
# Merge the two indices: EDBI and CPI
df_merged = df_edbi.merge(df_cpi, on = "Country")
df_merged.head()
# Out:
#        Country   EDBI  CPI
# 0  Afghanistan  44.20   16
# 1      Albania  66.99   35
# 2      Algeria  48.50   35
# 3       Angola  41.20   26
# 4    Argentina  58.18   45

# %%
# Check if there is any missing data
df_merged.isna().sum()
# Out:
# Country    0
# EDBI       0
# CPI        0
# dtype: int64

# %%
# Check the dimension of the merged dataset: 163 matching countries in the two datasets are retained 
df_merged.shape
# Out:
# (163, 3)

# %%
# Plot the indices and a linear regression model fit
sb.regplot(df_merged['CPI'], df_merged['EDBI'], color = "grey")

# %%
# Calculate the Pearson correlation coefficient 
np.corrcoef(df_merged['EDBI'], df_merged['CPI'])
# Out:
# array([[1.        , 0.74357284],
#        [0.74357284, 1.        ]])

# %%
# Divide the CPI data into three categories using percentiles based on the distribution of the data
df_merged["CPI_categories"] = pd.qcut(df_merged["CPI"], 3, labels=["High corruption", "Some corruption", "Low corruption"])

# %%
# Divide the EDBI data into three categories using percentiles based on the distribution of the data
df_merged["EDBI_categories"] = pd.qcut(df_merged["EDBI"], 3, labels=["Very difficult", "Relatively difficult", "Very easy"])

# %%
df_merged.head()
# Out:
#        Country   EDBI  CPI   CPI_categories       EDBI_categories
# 0  Afghanistan  44.20   16  High corruption        Very difficult
# 1      Albania  66.99   35  Some corruption  Relatively difficult
# 2      Algeria  48.50   35  Some corruption        Very difficult
# 3       Angola  41.20   26  High corruption        Very difficult
# 4    Argentina  58.18   45  Some corruption  Relatively difficult

# %%
# Compute ranks for both CPI ranking and EDBI ranking
df_merged["CPI_rank"] = df_merged["CPI"].rank(method='max', ascending= False)
df_merged["EDBI_rank"] = df_merged["EDBI"].rank(method='max', ascending= False)
df_merged.head()
# Out:
#        Country   EDBI  CPI   CPI_categories       EDBI_categories  CPI_rank  \
# 0  Afghanistan  44.20   16  High corruption        Very difficult     160.0
# 1      Albania  66.99   35  Some corruption  Relatively difficult     102.0
# 2      Algeria  48.50   35  Some corruption        Very difficult     102.0
# 3       Angola  41.20   26  High corruption        Very difficult     139.0
# 4    Argentina  58.18   45  Some corruption  Relatively difficult      61.0
#
#    EDBI_rank
# 0      147.0
# 1       72.0
# 2      135.0
# 3      151.0
# 4      108.0

# %%
# Show countries: high corruption and easy to do business
df_merged[(df_merged["CPI_categories"] == "High corruption") & (df_merged["EDBI_categories"] == "Very easy")].sort_values("CPI_rank", ascending = False)
# Out:
#        Country   EDBI  CPI   CPI_categories EDBI_categories  CPI_rank  \
# 98      Mexico  72.31   29  High corruption       Very easy     124.0
# 8   Azerbaijan  73.58   30  High corruption       Very easy     118.0
# 99     Moldova  73.13   32  High corruption       Very easy     112.0
#
#     EDBI_rank
# 98       51.0
# 8        42.0
# 99       45.0

# %%
# Show countries: low corruption and difficult to do business
df_merged[(df_merged["CPI_categories"] == "Low corruption") & (df_merged["EDBI_categories"] == "Very difficult")].sort_values("EDBI_rank", ascending = False)
# Out:
#        Country   EDBI  CPI  CPI_categories EDBI_categories  CPI_rank  \
# 61     Grenada  53.36   53  Low corruption  Very difficult      50.0
# 25  Cabo Verde  54.01   58  Low corruption  Very difficult      39.0
# 12    Barbados  57.68   62  Low corruption  Very difficult      31.0
#
#     EDBI_rank
# 61      125.0
# 25      122.0
# 12      109.0

# %% [markdown]
# End of notebook
